# %%
import matplotlib
print(matplotlib.__version__)

import matplotlib.pyplot as plt
import seaborn as sns

print("Working successfully")
# Out:
# 3.10.9
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import matplotlib
#       2 print(matplotlib.__version__)
#       3
#       4 import matplotlib.pyplot as plt
# ----> 5 import seaborn as sns
#       6
#       7 print("Working successfully")
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.4.6)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\3366a\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 4.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/9.9 MB 2.7 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.9 MB 2.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.9 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.9 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.9 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.9 MB 2.3 MB/s eta 0:00:03
#    -------------- ------------------------- 3.7/9.9 MB 2.2 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/9.9 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 2.2 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.9 MB 2.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.5/9.9 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.9 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.9 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 2.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/9.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------ --------- 7.6/9.9 MB 2.1 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 2.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 2.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 2.0 MB/s  0:00:04
# Installing collected packages: pandas, seaborn
#
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    ---------------------------------------- 0/2 [pandas]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    ---------------------------------------- 2/2 [seaborn]
#
# Successfully installed pandas-3.0.3 seaborn-0.13.2
